# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data Dictionary for Final Cleaned Data

# %% [markdown]
# This is data for % of women using particular forms of contraceptives in each state.
#
# The raw data was pulled from the Guttmacher [institute](https://data.guttmacher.org/states/table?state=AL+AK+AZ+AR+CA+CO+CT+DE+DC+FL+GA+HI+ID+IL+IN+IA+KS+KY+LA+ME+MD+MA+MI+MN+MS+MO+MT+NE+NV+NH+NJ+NM+NY+NC+ND+OH+OK+OR+PA+RI+SC+SD+TN+TX+UT+VT+VA+WA+WV+WI+WY&dataset=data&topics=283+282#footnotes) and is stored at path "../raw_data/contraceptive_use.csv".
#
# The cleaned data is stored at the path "../data/contraceptive_use.csv".

# %% [markdown]
# | column name | meaning |
# | ----------- | ------- |
# | state | U.S. state |
# | using | % of women aged 18-49 using contraceptives, 2017 [1] |
# | any | % of women at risk of unintended pregnancy using contraception, 2017 [3, 2] |
# | fem_steril | % of women at risk of unintended pregnancy relying on female sterilization, 2017 [3, 2] |
# | male_steril | % of women at risk of unintended pregnancy relying on male sterilization, 2017 [3, 2] |
# | implant | % of women at risk of unintended pregnancy relying on the contraceptive implant, 2017 [3, 2] |
# | iud | % of women at risk of unintended pregnancy relying on the IUD, 2017 [3, 2] |
# | pill | % of women at risk of unintended pregnancy relying on the pill, 2017 [3, 2] |
# | nonlarc_horm | % of women at risk of unintended pregnancy relying on other non-LARC hormonal methods, 2017 [3, 2] |
# | condoms | % of women at risk of unintended pregnancy relying on condoms, 2017 [4, 3, 2] |
# | withdrawal | % of women at risk of unintended pregnancy relying on withdrawal, 2017 [3, 2] |
# | other | % of women at risk of unintended pregnancy relying on other methods of contraception, 2017 [5, 3, 2] |
# | none | % of women at risk of unintended pregnancy not using a contraceptive method, 2017 [3, 2] |
# | year | year data is from |
# | STATEFP20 | state fips |
# | [1] | Data are available for the 38 states, plus the District of Columbia, that asked key questions regarding women's reproductive health as part of the Behavioral Risk Factor Surveillance System in 2017. Data are also available for Puerto Rico in the full report. |
# | [2] | Women were considered at risk of unintended pregnancy if they are aged 18–49, sexually active with one or more male partners, were not currently pregnant or trying to become pregnant, and had not had a hysterectomy. |
# | [3] | These data are available for the 38 states, plus the District of Columbia, that asked key questions regarding women's reproductive health as part of the 2017 Behavioral Risk Factor Surveillance System. Data for Puerto Rico are included in the full report. |
# | [4] | "Other non-LARC hormonal methods" are injectables, patches and vaginal rings. |
# | [5] | "Other contraceptive methods" are emergency contraception, diaphragms, cervical rings, cervical caps, rhythm method, natural family planning and spermicidal methods. |
# | Some NaN is from entires labelled with [6] | Estimate is unreliable (has a denominator of less than 50 respondents or a relative standard error greater than 30%). |

# %% [markdown]
# # Wrangling

# %% [markdown]
# ## Load Data

# %%
contraceptives = pd.read_csv("../raw_data/contraceptive_use.csv")
fips = pd.read_csv("../data/state_fips.csv", dtype={"STATEFP20": object}) # ensure leading 0's kept in fips

# %% [markdown]
# ## Preview Data

# %%
fips.head()
# Out:
#         STATE STATEFP20
# 0     Alabama        01
# 1      Alaska        02
# 2     Arizona        04
# 3    Arkansas        05
# 4  California        06

# %%
contraceptives
# Out:
#                                            U.S. State  \
# 0                                             Alabama
# 1                                              Alaska
# 2                                             Arizona
# 3                                            Arkansas
# 4                                          California
# 5                                            Colorado
# 6                                         Connecticut
# 7                                            Delaware
# 8                                District of Columbia
# 9                                             Florida
# 10                                            Georgia
# 11                                             Hawaii
# 12                                              Idaho
# 13                                           Illinois
# 14                                            Indiana
# 15                                               Iowa
# 16                                             Kansas
# 17                                           Kentucky
# 18                                          Louisiana
# 19                                              Maine
# 20                                           Maryland
# 21                                      Massachusetts
# 22                                           Michigan
# 23                                          Minnesota
# 24                                        Mississippi
# 25                                           Missouri
# 26                                            Montana
# 27                                           Nebraska
# 28                                             Nevada
# 29                                      New Hampshire
# 30                                         New Jersey
# 31                                         New Mexico
# 32                                           New York
# 33                                     North Carolina
# 34                                       North Dakota
# 35                                               Ohio
# 36                                           Oklahoma
# 37                                             Oregon
# 38                                       Pennsylvania
# 39                                       Rhode Island
# 40                                     South Carolina
# 41                                       South Dakota
# 42                                          Tennessee
# 43                                              Texas
# 44                                               Utah
# 45                                            Vermont
# 46                                           Virginia
# 47                                         Washington
# 48                                      West Virginia
# 49                                          Wisconsin
# 50                                            Wyoming
# 51                                            Sources
# 52  1. Data are available for the 38 states, plus ...
# 53  Sources: 1. State-Level Estimates of Contracep...
#
#    % of women aged 18-49 using contraceptives, 2017 [1]  \
# 0                                                71.5
# 1                                                76.5
# 2                                                64.2
# 3                                                 NaN
# 4                                                  72
# 5                                                 NaN
# 6                                                68.8
# 7                                                62.5
# 8                                                65.5
# 9                                                67.9
# 10                                               64.8
# 11                                               61.8
# 12                                               73.8
# 13                                                NaN
# 14                                                 72
# 15                                               74.7
# 16                                               72.4
# 17                                                NaN
# 18                                               70.9
# 19                                                 78
# 20                                               72.1
# 21                                               72.1
# 22                                                NaN
# 23                                               70.1
# 24                                               65.5
# 25                                               69.1
# 26                                                NaN
# 27                                               67.9
# 28                                               68.4
# 29                                                NaN
# 30                                               67.5
# 31                                               73.9
# 32                                               68.3
# 33                                               73.8
# 34                                                NaN
# 35                                               65.7
# 36                                                 70
# 37                                               77.7
# 38                                               76.1
# 39                                                NaN
# 40                                               72.2
# 41                                               72.4
# 42                                                NaN
# 43                                               63.1
# 44                                               74.9
# 45                                                NaN
# 46                                               71.3
# 47                                                NaN
# 48                                               70.2
# 49                                               67.1
# 50                                               75.4
# 51                                      Sources:  [1]
# 52                                                NaN
# 53                                                NaN
#
#    % of women at risk of unintended pregnancy using contraception, 2017 [3, 2]  \
# 0                                                75.9
# 1                                                82.7
# 2                                                67.4
# 3                                                 NaN
# 4                                                76.6
# 5                                                 NaN
# 6                                                72.8
# 7                                                66.2
# 8                                                71.1
# 9                                                72.6
# 10                                               68.5
# 11                                               69.2
# 12                                               77.5
# 13                                                NaN
# 14                                               76.7
# 15                                               78.6
# 16                                               75.6
# 17                                                NaN
# 18                                               71.4
# 19                                               84.1
# 20                                               74.4
# 21                                               78.2
# 22                                                NaN
# 23                                               73.7
# 24                                               71.9
# 25                                               75.1
# 26                                                NaN
# 27                                               71.5
# 28                                               74.5
# 29                                                NaN
# 30                                               72.1
# 31                                               80.4
# 32                                               75.6
# 33                                               77.2
# 34                                                NaN
# 35                                               70.7
# 36                                               73.8
# 37                                               79.8
# 38                                               83.1
# 39                                                NaN
# 40                                               75.6
# 41                                               77.9
# 42                                                NaN
# 43                                               69.1
# 44                                               79.9
# 45                                                NaN
# 46                                               77.9
# 47                                                NaN
# 48                                               74.4
# 49                                               71.1
# 50                                               79.9
# 51                                      Sources:  [1]
# 52                                                NaN
# 53                                                NaN
#
#    % of women at risk of unintended pregnancy relying on female sterilization, 2017 [3, 2]  \
# 0                                                19.3
# 1                                                10.6
# 2                                                12.3
# 3                                                 NaN
# 4                                                 9.1
# 5                                                 NaN
# 6                                                 7.4
# 7                                                14.6
# 8                                                 3.2
# 9                                                12.1
# 10                                               16.6
# 11                                                9.3
# 12                                               10.6
# 13                                                NaN
# 14                                               16.8
# 15                                               12.8
# 16                                               13.9
# 17                                                NaN
# 18                                               15.1
# 19                                               13.4
# 20                                                7.9
# 21                                                8.5
# 22                                                NaN
# 23                                                9.6
# 24                                               17.8
# 25                                                 19
# 26                                                NaN
# 27                                               12.1
# 28                                               13.6
# 29                                                NaN
# 30                                               11.4
# 31                                               16.1
# 32                                                8.2
# 33                                               17.2
# 34                                                NaN
# 35                                               15.3
# 36                                               18.7
# 37                                               12.9
# 38                                               16.5
# 39                                                NaN
# 40                                               16.8
# 41                                               15.3
# 42                                                NaN
# 43                                               15.1
# 44                                                8.1
# 45                                                NaN
# 46                                                 12
# 47                                                NaN
# 48                                               27.4
# 49                                               10.2
# 50                                               21.1
# 51                                      Sources:  [1]
# 52                                                NaN
# 53                                                NaN
#
#    % of women at risk of unintended pregnancy relying on male sterilization, 2017 [3, 2]  \
# 0                                                 4.7
# 1                                               u [6]
# 2                                                 4.1
# 3                                                 NaN
# 4                                                 1.3
# 5                                                 NaN
# 6                                                 3.5
# 7                                               u [6]
# 8                                               u [6]
# 9                                                 3.1
# 10                                              u [6]
# 11                                              u [6]
# 12                                                4.8
# 13                                                NaN
# 14                                                3.9
# 15                                                5.1
# 16                                                4.3
# 17                                                NaN
# 18                                                3.1
# 19                                            n/a [6]
# 20                                                3.4
# 21                                              u [6]
# 22                                                NaN
# 23                                                  4
# 24                                              u [6]
# 25                                                4.2
# 26                                                NaN
# 27                                                4.3
# 28                                                3.7
# 29                                                NaN
# 30                                                1.8
# 31                                                2.5
# 32                                                1.6
# 33                                                4.3
# 34                                                NaN
# 35                                                3.4
# 36                                            n/a [6]
# 37                                                2.7
# 38                                                2.8
# 39                                                NaN
# 40                                                3.5
# 41                                                3.8
# 42                                                NaN
# 43                                            n/a [6]
# 44                                                  5
# 45                                                NaN
# 46                                                2.7
# 47                                                NaN
# 48                                                4.9
# 49                                                5.7
# 50                                                4.1
# 51                                      Sources:  [1]
# 52                                                NaN
# 53                                                NaN
#
#    % of women at risk of unintended pregnancy relying on the contraceptive implant, 2017 [3, 2]  \
# 0                                               u [6]
# 1                                               u [6]
# 2                                                 2.2
# 3                                                 NaN
# 4                                                 3.5
# 5                                                 NaN
# 6                                                 2.4
# 7                                                 6.4
# 8                                               u [6]
# 9                                                   5
# 10                                              u [6]
# 11                                                4.4
# 12                                              u [6]
# 13                                                NaN
# 14                                              u [6]
# 15                                                5.2
# 16                                                2.6
# 17                                                NaN
# 18                                              u [6]
# 19                                              u [6]
# 20                                              u [6]
# 21                                              u [6]
# 22                                                NaN
# 23                                                  5
# 24                                              u [6]
# 25                                                2.9
# 26                                                NaN
# 27                                                3.5
# 28                                            n/a [6]
# 29                                                NaN
# 30                                                2.6
# 31                                                  8
# 32                                              u [6]
# 33                                              u [6]
# 34                                                NaN
# 35                                                4.1
# 36                                              u [6]
# 37                                              u [6]
# 38                                              u [6]
# 39                                                NaN
# 40                                                2.2
# 41                                              u [6]
# 42                                                NaN
# 43                                              u [6]
# 44                                              u [6]
# 45                                                NaN
# 46                                                  u
# 47                                                NaN
# 48                                              u [6]
# 49                                              u [6]
# 50                                                4.9
# 51                                      Sources:  [1]
# 52                                                NaN
# 53                                                NaN
#
#    % of women at risk of unintended pregnancy relying on the IUD, 2017 [3, 2]  \
# 0                                                 5.4
# 1                                                20.6
# 2                                                 9.3
# 3                                                 NaN
# 4                                                 9.4
# 5                                                 NaN
# 6                                                 8.4
# 7                                                 6.7
# 8                                                 9.2
# 9                                                 7.6
# 10                                                6.6
# 11                                                8.3
# 12                                               18.1
# 13                                                NaN
# 14                                               10.1
# 15                                               10.4
# 16                                                9.8
# 17                                                NaN
# 18                                                4.5
# 19                                                 24
# 20                                               11.3
# 21                                                 12
# 22                                                NaN
# 23                                               11.7
# 24                                                7.1
# 25                                                7.8
# 26                                                NaN
# 27                                                  8
# 28                                               13.2
# 29                                                NaN
# 30                                                7.8
# 31                                               15.3
# 32                                               10.2
# 33                                                9.5
# 34                                                NaN
# 35                                                8.3
# 36                                                  9
# 37                                               19.9
# 38                                                9.1
# 39                                                NaN
# 40                                                  7
# 41                                                9.9
# 42                                                NaN
# 43                                                6.2
# 44                                               21.4
# 45                                                NaN
# 46                                               10.4
# 47                                                NaN
# 48                                                8.7
# 49                                               10.6
# 50                                               11.7
# 51                                      Sources:  [1]
# 52                                                NaN
# 53                                                NaN
#
#    % of women at risk of unintended pregnancy relying on the pill, 2017 [3, 2]  \
# 0                                                20.6
# 1                                                10.2
# 2                                                14.7
# 3                                                 NaN
# 4                                                19.7
# 5                                                 NaN
# 6                                                21.9
# 7                                                13.4
# 8                                                13.5
# 9                                                15.7
# 10                                               12.8
# 11                                               20.1
# 12                                               17.7
# 13                                                NaN
# 14                                               17.2
# 15                                               22.7
# 16                                               19.2
# 17                                                NaN
# 18                                               17.9
# 19                                                 19
# 20                                               18.8
# 21                                               25.4
# 22                                                NaN
# 23                                               19.5
# 24                                               14.2
# 25                                               17.1
# 26                                                NaN
# 27                                               18.2
# 28                                               13.8
# 29                                                NaN
# 30                                               16.7
# 31                                               13.6
# 32                                               14.7
# 33                                               17.3
# 34                                                NaN
# 35                                               14.2
# 36                                               21.5
# 37                                               16.9
# 38                                               21.2
# 39                                                NaN
# 40                                                 17
# 41                                               23.3
# 42                                                NaN
# 43                                               13.2
# 44                                               17.1
# 45                                                NaN
# 46                                                 18
# 47                                                NaN
# 48                                               14.7
# 49                                               18.9
# 50                                               16.9
# 51                                      Sources:  [1]
# 52                                                NaN
# 53                                                NaN
#
#    % of women at risk of unintended pregnancy relying on other non-LARC hormonal methods, 2017 [3, 2]  \
# 0                                               u [6]
# 1                                               u [6]
# 2                                               u [6]
# 3                                                 NaN
# 4                                                 3.1
# 5                                                 NaN
# 6                                                 1.5
# 7                                               u [6]
# 8                                               u [6]
# 9                                                 1.7
# 10                                              u [6]
# 11                                                3.9
# 12                                              u [6]
# 13                                                NaN
# 14                                                2.5
# 15                                                4.7
# 16                                                2.8
# 17                                                NaN
# 18                                              u [6]
# 19                                              u [6]
# 20                                                2.1
# 21                                              u [6]
# 22                                                NaN
# 23                                                1.5
# 24                                              u [6]
# 25                                              u [6]
# 26                                                NaN
# 27                                              u [6]
# 28                                              u [6]
# 29                                                NaN
# 30                                                2.1
# 31                                                3.4
# 32                                                3.1
# 33                                                3.6
# 34                                                NaN
# 35                                                3.6
# 36                                              u [6]
# 37                                              u [6]
# 38                                                5.7
# 39                                                NaN
# 40                                                  3
# 41                                              u [6]
# 42                                                NaN
# 43                                              u [6]
# 44                                                3.1
# 45                                                NaN
# 46                                                2.9
# 47                                                NaN
# 48                                              u [6]
# 49                                                5.9
# 50                                                  4
# 51                                      Sources:  [1]
# 52                                                NaN
# 53                                                NaN
#
#    % of women at risk of unintended pregnancy relying on condoms, 2017 [4, 3, 2]  \
# 0                                                17.1
# 1                                                24.2
# 2                                                16.5
# 3                                                 NaN
# 4                                                22.7
# 5                                                 NaN
# 6                                                20.6
# 7                                                  14
# 8                                                28.9
# 9                                                20.3
# 10                                               18.4
# 11                                               14.2
# 12                                               15.2
# 13                                                NaN
# 14                                               17.3
# 15                                               13.8
# 16                                               17.5
# 17                                                NaN
# 18                                               22.7
# 19                                               13.1
# 20                                               23.3
# 21                                               15.3
# 22                                                NaN
# 23                                               14.8
# 24                                               18.4
# 25                                               17.2
# 26                                                NaN
# 27                                               16.5
# 28                                               14.3
# 29                                                NaN
# 30                                               23.6
# 31                                               15.9
# 32                                               24.6
# 33                                               15.3
# 34                                                NaN
# 35                                               15.2
# 36                                               12.9
# 37                                               14.5
# 38                                               20.3
# 39                                                NaN
# 40                                                 21
# 41                                               17.9
# 42                                                NaN
# 43                                               20.3
# 44                                               18.2
# 45                                                NaN
# 46                                               20.3
# 47                                                NaN
# 48                                               10.1
# 49                                               14.8
# 50                                               12.5
# 51                                      Sources:  [1]
# 52                                                NaN
# 53                                                NaN
#
#    % of women at risk of unintended pregnancy relying on withdrawal, 2017 [3, 2]  \
# 0                                               u [6]
# 1                                               u [6]
# 2                                                 1.1
# 3                                                 NaN
# 4                                                 2.3
# 5                                                 NaN
# 6                                               u [6]
# 7                                               u [6]
# 8                                                 2.9
# 9                                                 0.8
# 10                                              u [6]
# 11                                                  2
# 12                                              u [6]
# 13                                                NaN
# 14                                                1.6
# 15                                              u [6]
# 16                                              u [6]
# 17                                                NaN
# 18                                              u [6]
# 19                                              u [6]
# 20                                              u [6]
# 21                                              u [6]
# 22                                                NaN
# 23                                                1.5
# 24                                              u [6]
# 25                                              u [6]
# 26                                                NaN
# 27                                              u [6]
# 28                                              u [6]
# 29                                                NaN
# 30                                              u [6]
# 31                                              u [6]
# 32                                                3.1
# 33                                              u [6]
# 34                                                NaN
# 35                                              u [6]
# 36                                              u [6]
# 37                                                1.7
# 38                                              u [6]
# 39                                                NaN
# 40                                                1.8
# 41                                              u [6]
# 42                                                NaN
# 43                                              u [6]
# 44                                              u [6]
# 45                                                NaN
# 46                                              u [6]
# 47                                                NaN
# 48                                              u [6]
# 49                                              u [6]
# 50                                              u [6]
# 51                                      Sources:  [1]
# 52                                                NaN
# 53                                                NaN
#
#    % of women at risk of unintended pregnancy relying on other methods of contraception, 2017 [5, 3, 2]  \
# 0                                                 4.2
# 1                                               u [6]
# 2                                                 6.3
# 3                                                 NaN
# 4                                                 5.4
# 5                                                 NaN
# 6                                                 6.1
# 7                                                 6.1
# 8                                                 8.6
# 9                                                 6.3
# 10                                                7.1
# 11                                                5.6
# 12                                                7.3
# 13                                                NaN
# 14                                                5.6
# 15                                                3.2
# 16                                                4.3
# 17                                                NaN
# 18                                                3.7
# 19                                              u [6]
# 20                                                5.6
# 21                                                  7
# 22                                                NaN
# 23                                                6.2
# 24                                              u [6]
# 25                                                5.9
# 26                                                NaN
# 27                                                5.5
# 28                                              u [6]
# 29                                                NaN
# 30                                                4.2
# 31                                                4.2
# 32                                                8.1
# 33                                              u [6]
# 34                                                NaN
# 35                                                  5
# 36                                              u [6]
# 37                                                7.7
# 38                                                  4
# 39                                                NaN
# 40                                                3.4
# 41                                              u [6]
# 42                                                NaN
# 43                                                4.8
# 44                                                4.4
# 45                                                NaN
# 46                                                5.8
# 47                                                NaN
# 48                                                4.1
# 49                                              u [6]
# 50                                              u [6]
# 51                                      Sources:  [1]
# 52                                                NaN
# 53                                                NaN
#
#    % of women at risk of unintended pregnancy not using a contraceptive method, 2017 [3, 2]
# 0                                                24.1
# 1                                                17.3
# 2                                                32.6
# 3                                                 NaN
# 4                                                23.4
# 5                                                 NaN
# 6                                                27.2
# 7                                                33.8
# 8                                                28.9
# 9                                                27.4
# 10                                               31.5
# 11                                               30.8
# 12                                               22.5
# 13                                                NaN
# 14                                               23.3
# 15                                               21.4
# 16                                               24.4
# 17                                                NaN
# 18                                               28.6
# 19                                               15.9
# 20                                               25.6
# 21                                               21.8
# 22                                                NaN
# 23                                               26.3
# 24                                               28.1
# 25                                               24.9
# 26                                                NaN
# 27                                               28.5
# 28                                               25.5
# 29                                                NaN
# 30                                               27.9
# 31                                               19.6
# 32                                               24.4
# 33                                               22.8
# 34                                                NaN
# 35                                               29.3
# 36                                               26.2
# 37                                               20.2
# 38                                               16.9
# 39                                                NaN
# 40                                               24.4
# 41                                               22.1
# 42                                                NaN
# 43                                               30.9
# 44                                               20.1
# 45                                                NaN
# 46                                               22.1
# 47                                                NaN
# 48                                               25.6
# 49                                               28.9
# 50                                               20.1
# 51                                      Sources:  [1]
# 52                                                NaN
# 53                                                NaN

# %% [markdown]
# ## Clean Data

# %%
# give columns shorter names
contraceptives.rename(columns={"U.S. State": "state", 
                               "% of women aged 18-49 using contraceptives, 2017 [1]": "using",
                               "% of women at risk of unintended pregnancy using contraception, 2017 [3, 2]": "any",
                               "% of women at risk of unintended pregnancy relying on female sterilization, 2017 [3, 2]": "fem_steril",
                               "% of women at risk of unintended pregnancy relying on male sterilization, 2017 [3, 2]": "male_steril",
                               "% of women at risk of unintended pregnancy relying on the contraceptive implant, 2017 [3, 2]": "implant",
                               "% of women at risk of unintended pregnancy relying on the IUD, 2017 [3, 2]": "iud",
                               "% of women at risk of unintended pregnancy relying on the pill, 2017 [3, 2]": "pill",
                               "% of women at risk of unintended pregnancy relying on other non-LARC hormonal methods, 2017 [3, 2]": "nonlarc_horm",
                               "% of women at risk of unintended pregnancy relying on condoms, 2017 [4, 3, 2]": "condoms",
                               "% of women at risk of unintended pregnancy relying on withdrawal, 2017 [3, 2]": "withdrawal",
                               "% of women at risk of unintended pregnancy relying on other methods of contraception, 2017 [5, 3, 2]": "other",
                               "% of women at risk of unintended pregnancy not using a contraceptive method, 2017 [3, 2]": "none"
                              },
                     inplace=True)

# %%
# add a column indicating year of data
contraceptives["year"] = 2017

# %%
# drop footer rows without data
contraceptives.drop([51, 52, 53], inplace=True)

# %%
# add state fips column

# check that name columns are all equal before merging
# contraceptives["state"] == fips["STATE"]

contraceptives = contraceptives.merge(right=fips, left_on="state", right_on="STATE")
contraceptives.drop(["STATE"], axis=1, inplace=True)

# %%
contraceptives.head()
# Out:
#         state using   any fem_steril male_steril implant   iud  pill  \
# 0     Alabama  71.5  75.9       19.3         4.7   u [6]   5.4  20.6
# 1      Alaska  76.5  82.7       10.6       u [6]   u [6]  20.6  10.2
# 2     Arizona  64.2  67.4       12.3         4.1     2.2   9.3  14.7
# 3    Arkansas   NaN   NaN        NaN         NaN     NaN   NaN   NaN
# 4  California    72  76.6        9.1         1.3     3.5   9.4  19.7
#
#   nonlarc_horm condoms withdrawal  other  none  year STATEFP20
# 0        u [6]    17.1      u [6]    4.2  24.1  2017        01
# 1        u [6]    24.2      u [6]  u [6]  17.3  2017        02
# 2        u [6]    16.5        1.1    6.3  32.6  2017        04
# 3          NaN     NaN        NaN    NaN   NaN  2017        05
# 4          3.1    22.7        2.3    5.4  23.4  2017        06

# %%
# set all unavailable ("u [6]") and not applicable ("n/a [6]") to NaN
contraceptives.dtypes
# Out:
# state           object
# using           object
# any             object
# fem_steril      object
# male_steril     object
# implant         object
# iud             object
# pill            object
# nonlarc_horm    object
# condoms         object
# withdrawal      object
# other           object
# none            object
# year             int64
# STATEFP20       object
# dtype: object

# %%
cols = contraceptives.columns.drop(["state", "STATEFP20"])

# %%
contraceptives[cols] = contraceptives[cols].apply(pd.to_numeric, errors="coerce")

# %%
contraceptives
# Out:
#                    state  using   any  fem_steril  male_steril  implant   iud  \
# 0                Alabama   71.5  75.9        19.3          4.7      NaN   5.4
# 1                 Alaska   76.5  82.7        10.6          NaN      NaN  20.6
# 2                Arizona   64.2  67.4        12.3          4.1      2.2   9.3
# 3               Arkansas    NaN   NaN         NaN          NaN      NaN   NaN
# 4             California   72.0  76.6         9.1          1.3      3.5   9.4
# 5               Colorado    NaN   NaN         NaN          NaN      NaN   NaN
# 6            Connecticut   68.8  72.8         7.4          3.5      2.4   8.4
# 7               Delaware   62.5  66.2        14.6          NaN      6.4   6.7
# 8   District of Columbia   65.5  71.1         3.2          NaN      NaN   9.2
# 9                Florida   67.9  72.6        12.1          3.1      5.0   7.6
# 10               Georgia   64.8  68.5        16.6          NaN      NaN   6.6
# 11                Hawaii   61.8  69.2         9.3          NaN      4.4   8.3
# 12                 Idaho   73.8  77.5        10.6          4.8      NaN  18.1
# 13              Illinois    NaN   NaN         NaN          NaN      NaN   NaN
# 14               Indiana   72.0  76.7        16.8          3.9      NaN  10.1
# 15                  Iowa   74.7  78.6        12.8          5.1      5.2  10.4
# 16                Kansas   72.4  75.6        13.9          4.3      2.6   9.8
# 17              Kentucky    NaN   NaN         NaN          NaN      NaN   NaN
# 18             Louisiana   70.9  71.4        15.1          3.1      NaN   4.5
# 19                 Maine   78.0  84.1        13.4          NaN      NaN  24.0
# 20              Maryland   72.1  74.4         7.9          3.4      NaN  11.3
# 21         Massachusetts   72.1  78.2         8.5          NaN      NaN  12.0
# 22              Michigan    NaN   NaN         NaN          NaN      NaN   NaN
# 23             Minnesota   70.1  73.7         9.6          4.0      5.0  11.7
# 24           Mississippi   65.5  71.9        17.8          NaN      NaN   7.1
# 25              Missouri   69.1  75.1        19.0          4.2      2.9   7.8
# 26               Montana    NaN   NaN         NaN          NaN      NaN   NaN
# 27              Nebraska   67.9  71.5        12.1          4.3      3.5   8.0
# 28                Nevada   68.4  74.5        13.6          3.7      NaN  13.2
# 29         New Hampshire    NaN   NaN         NaN          NaN      NaN   NaN
# 30            New Jersey   67.5  72.1        11.4          1.8      2.6   7.8
# 31            New Mexico   73.9  80.4        16.1          2.5      8.0  15.3
# 32              New York   68.3  75.6         8.2          1.6      NaN  10.2
# 33        North Carolina   73.8  77.2        17.2          4.3      NaN   9.5
# 34          North Dakota    NaN   NaN         NaN          NaN      NaN   NaN
# 35                  Ohio   65.7  70.7        15.3          3.4      4.1   8.3
# 36              Oklahoma   70.0  73.8        18.7          NaN      NaN   9.0
# 37                Oregon   77.7  79.8        12.9          2.7      NaN  19.9
# 38          Pennsylvania   76.1  83.1        16.5          2.8      NaN   9.1
# 39          Rhode Island    NaN   NaN         NaN          NaN      NaN   NaN
# 40        South Carolina   72.2  75.6        16.8          3.5      2.2   7.0
# 41          South Dakota   72.4  77.9        15.3          3.8      NaN   9.9
# 42             Tennessee    NaN   NaN         NaN          NaN      NaN   NaN
# 43                 Texas   63.1  69.1        15.1          NaN      NaN   6.2
# 44                  Utah   74.9  79.9         8.1          5.0      NaN  21.4
# 45               Vermont    NaN   NaN         NaN          NaN      NaN   NaN
# 46              Virginia   71.3  77.9        12.0          2.7      NaN  10.4
# 47            Washington    NaN   NaN         NaN          NaN      NaN   NaN
# 48         West Virginia   70.2  74.4        27.4          4.9      NaN   8.7
# 49             Wisconsin   67.1  71.1        10.2          5.7      NaN  10.6
# 50               Wyoming   75.4  79.9        21.1          4.1      4.9  11.7
#
#     pill  nonlarc_horm  condoms  withdrawal  other  none  year STATEFP20
# 0   20.6           NaN     17.1         NaN    4.2  24.1  2017        01
# 1   10.2           NaN     24.2         NaN    NaN  17.3  2017        02
# 2   14.7           NaN     16.5         1.1    6.3  32.6  2017        04
# 3    NaN           NaN      NaN         NaN    NaN   NaN  2017        05
# 4   19.7           3.1     22.7         2.3    5.4  23.4  2017        06
# 5    NaN           NaN      NaN         NaN    NaN   NaN  2017        08
# 6   21.9           1.5     20.6         NaN    6.1  27.2  2017        09
# 7   13.4           NaN     14.0         NaN    6.1  33.8  2017        10
# 8   13.5           NaN     28.9         2.9    8.6  28.9  2017        11
# 9   15.7           1.7     20.3         0.8    6.3  27.4  2017        12
# 10  12.8           NaN     18.4         NaN    7.1  31.5  2017        13
# 11  20.1           3.9     14.2         2.0    5.6  30.8  2017        15
# 12  17.7           NaN     15.2         NaN    7.3  22.5  2017        16
# 13   NaN           NaN      NaN         NaN    NaN   NaN  2017        17
# 14  17.2           2.5     17.3         1.6    5.6  23.3  2017        18
# 15  22.7           4.7     13.8         NaN    3.2  21.4  2017        19
# 16  19.2           2.8     17.5         NaN    4.3  24.4  2017        20
# 17   NaN           NaN      NaN         NaN    NaN   NaN  2017        21
# 18  17.9           NaN     22.7         NaN    3.7  28.6  2017        22
# 19  19.0           NaN     13.1         NaN    NaN  15.9  2017        23
# 20  18.8           2.1     23.3         NaN    5.6  25.6  2017        24
# 21  25.4           NaN     15.3         NaN    7.0  21.8  2017        25
# 22   NaN           NaN      NaN         NaN    NaN   NaN  2017        26
# 23  19.5           1.5     14.8         1.5    6.2  26.3  2017        27
# 24  14.2           NaN     18.4         NaN    NaN  28.1  2017        28
# 25  17.1           NaN     17.2         NaN    5.9  24.9  2017        29
# 26   NaN           NaN      NaN         NaN    NaN   NaN  2017        30
# 27  18.2           NaN     16.5         NaN    5.5  28.5  2017        31
# 28  13.8           NaN     14.3         NaN    NaN  25.5  2017        32
# 29   NaN           NaN      NaN         NaN    NaN   NaN  2017        33
# 30  16.7           2.1     23.6         NaN    4.2  27.9  2017        34
# 31  13.6           3.4     15.9         NaN    4.2  19.6  2017        35
# 32  14.7           3.1     24.6         3.1    8.1  24.4  2017        36
# 33  17.3           3.6     15.3         NaN    NaN  22.8  2017        37
# 34   NaN           NaN      NaN         NaN    NaN   NaN  2017        38
# 35  14.2           3.6     15.2         NaN    5.0  29.3  2017        39
# 36  21.5           NaN     12.9         NaN    NaN  26.2  2017        40
# 37  16.9           NaN     14.5         1.7    7.7  20.2  2017        41
# 38  21.2           5.7     20.3         NaN    4.0  16.9  2017        42
# 39   NaN           NaN      NaN         NaN    NaN   NaN  2017        44
# 40  17.0           3.0     21.0         1.8    3.4  24.4  2017        45
# 41  23.3           NaN     17.9         NaN    NaN  22.1  2017        46
# 42   NaN           NaN      NaN         NaN    NaN   NaN  2017        47
# 43  13.2           NaN     20.3         NaN    4.8  30.9  2017        48
# 44  17.1           3.1     18.2         NaN    4.4  20.1  2017        49
# 45   NaN           NaN      NaN         NaN    NaN   NaN  2017        50
# 46  18.0           2.9     20.3         NaN    5.8  22.1  2017        51
# 47   NaN           NaN      NaN         NaN    NaN   NaN  2017        53
# 48  14.7           NaN     10.1         NaN    4.1  25.6  2017        54
# 49  18.9           5.9     14.8         NaN    NaN  28.9  2017        55
# 50  16.9           4.0     12.5         NaN    NaN  20.1  2017        56

# %% [markdown]
# ## Save Cleaned Data

# %%
# contraceptives.to_csv("../data/contraceptive_use.csv", index=False)

# %%
test = pd.read_csv("../data/contraceptive_use.csv", dtype={"STATEFP20": object})

# %%
test.head()
# Out:
#         state  using   any  fem_steril  male_steril  implant   iud  pill  \
# 0     Alabama   71.5  75.9        19.3          4.7      NaN   5.4  20.6
# 1      Alaska   76.5  82.7        10.6          NaN      NaN  20.6  10.2
# 2     Arizona   64.2  67.4        12.3          4.1      2.2   9.3  14.7
# 3    Arkansas    NaN   NaN         NaN          NaN      NaN   NaN   NaN
# 4  California   72.0  76.6         9.1          1.3      3.5   9.4  19.7
#
#    nonlarc_horm  condoms  withdrawal  other  none  year STATEFP20
# 0           NaN     17.1         NaN    4.2  24.1  2017        01
# 1           NaN     24.2         NaN    NaN  17.3  2017        02
# 2           NaN     16.5         1.1    6.3  32.6  2017        04
# 3           NaN      NaN         NaN    NaN   NaN  2017        05
# 4           3.1     22.7         2.3    5.4  23.4  2017        06
