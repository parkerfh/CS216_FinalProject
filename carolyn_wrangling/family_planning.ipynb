# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data Dictionary for Final Cleaned Data

# %% [markdown]
# This is data pulled for publically-funded family planning in each state. Note that not all data is from the same year. Data for number of family planning centers and total expenditures is from 2015, the remaining data is from 2016.
#
# The raw data was pulled from the [Guttmacher institute](https://data.guttmacher.org/states/table?state=AL+AK+AZ+AR+CA+CO+CT+DE+DC+FL+GA+HI+ID+IL+IN+IA+KS+KY+LA+ME+MD+MA+MI+MN+MS+MO+MT+NE+NV+NH+NJ+NM+NY+NC+ND+OH+OK+OR+PA+RI+SC+SD+TN+TX+UT+VT+VA+WA+WV+WI+WY&dataset=data&topics=105+102+256+125) and is stored at the path "../raw_data/family_planning.csv".
#
# The cleaned data is stored at the path "../data/family_planning.csv".

# %% [markdown]
# | column name | meaning |
# | ----------- | ------- |
# | state | U.S. State |
# | perc_need_met16 | % of likely need met by publicly funded centers, 2016 |
# | num_served16 | No. of female contraceptive clients younger than 20 served at publicly funded centers, 2016 |
# | num_u20_served16 | No. of female contraceptive clients younger than 20 served at publicly funded centers, 2016 |
# | num_centers15 | No. of publicly funded family planning centers, 2015 |
# | total_expend15 | Total reported public expenditures for family planning client services in dollars, 2015 |
# | STATEFP20 | state fips |

# %% [markdown]
# # Wrangling

# %% [markdown]
# ## Load data

# %%
planning = pd.read_csv("../raw_data/family_planning.csv")
fips = pd.read_csv("../data/state_fips.csv", dtype={"STATEFP20": object}) # ensure leading 0's kept in fips

# %% [markdown]
# ## Preview data

# %%
fips.head()
# Out:
#         STATE STATEFP20
# 0     Alabama        01
# 1      Alaska        02
# 2     Arizona        04
# 3    Arkansas        05
# 4  California        06

# %%
planning.head()
# Out:
#    U.S. State % of likely need met by publicly funded centers, 2016  \
# 0     Alabama                                                 28
# 1      Alaska                                                 54
# 2     Arizona                                                 19
# 3    Arkansas                                                 23
# 4  California                                                 64
#
#   No. of female contraceptive clients served at publicly funded centers , 2016  \
# 0                                             97,600
# 1                                             21,640
# 2                                             88,140
# 3                                             50,960
# 4                                          1,618,010
#
#   No. of female contraceptive clients younger than 20 served at publicly funded centers, 2016  \
# 0                                             20,300
# 1                                              4,750
# 2                                             16,500
# 3                                             10,610
# 4                                            252,840
#
#   No. of publicly funded family planning centers, 2015  \
# 0                                                187
# 1                                                157
# 2                                                232
# 3                                                163
# 4                                              1,697
#
#   Total reported public expenditures for family planning client services (in 000s of dollars), 2015
# 0                                             69,742
# 1                                             10,158
# 2                                             57,560
# 3                                             11,397
# 4                                            454,706

# %% [markdown]
# ## Clean Data

# %%
planning.columns
# Out:
# Index(['U.S. State', '% of likely need met by publicly funded centers, 2016',
#        'No. of female contraceptive clients served at publicly funded centers , 2016',
#        'No. of female contraceptive clients younger than 20 served at publicly funded centers, 2016',
#        'No. of publicly funded family planning centers, 2015',
#        'Total reported public expenditures for family planning client services (in 000s of dollars), 2015'],
#       dtype='object')

# %%
# give columns shorter names
planning.rename(columns={'U.S. State': 'state',
                        '% of likely need met by publicly funded centers, 2016': 'perc_need_met16',
                        'No. of female contraceptive clients served at publicly funded centers , 2016': 'num_served16',
                        'No. of female contraceptive clients younger than 20 served at publicly funded centers, 2016': 'num_u20_served16',
                        'No. of publicly funded family planning centers, 2015': 'num_centers15',
                        'Total reported public expenditures for family planning client services (in 000s of dollars), 2015': 'total_expend15'},
               inplace=True)

# %%
# drop footer rows without data
planning.drop([51, 52, 53], inplace=True)

# %%
# add state fips column

# check that name columns are all equal before merging
# planning["state"] == fips["STATE"]

planning = planning.merge(right=fips, left_on="state", right_on="STATE")
planning.drop(["STATE"], axis=1, inplace=True)

# %%
planning.head()
# Out:
#         state perc_need_met16 num_served16 num_u20_served16 num_centers15  \
# 0     Alabama              28       97,600           20,300           187
# 1      Alaska              54       21,640            4,750           157
# 2     Arizona              19       88,140           16,500           232
# 3    Arkansas              23       50,960           10,610           163
# 4  California              64    1,618,010          252,840         1,697
#
#   total_expend15 STATEFP20
# 0         69,742        01
# 1         10,158        02
# 2         57,560        04
# 3         11,397        05
# 4        454,706        06

# %%
# convert appropriate columns to numerical
planning.dtypes
# Out:
# state               object
# perc_need_met16     object
# num_served16        object
# num_u20_served16    object
# num_centers15       object
# total_expend15      object
# STATEFP20           object
# dtype: object

# %%
cols = planning.columns.drop(["state", "STATEFP20"])

# %%
# get rid of commas in numbers
planning[cols] = planning[cols].replace({',': ''}, regex=True)
planning[cols] = planning[cols].apply(pd.to_numeric, errors="coerce")

# %%
# original data for total expenditures was in 1000's of dollars
# convert to literal dollars
planning["total_expend15"] = planning["total_expend15"] * 1000

# %%
planning
# Out:
#                    state  perc_need_met16  num_served16  num_u20_served16  \
# 0                Alabama               28         97600             20300
# 1                 Alaska               54         21640              4750
# 2                Arizona               19         88140             16500
# 3               Arkansas               23         50960             10610
# 4             California               64       1618010            252840
# 5               Colorado               35        115490             23720
# 6            Connecticut               38         68130             14160
# 7               Delaware               30         16080              4510
# 8   District of Columbia               88         43600              7370
# 9                Florida               16        214450             40050
# 10               Georgia               26        194910             42860
# 11                Hawaii               21         13830              2560
# 12                 Idaho               18         20880              4340
# 13              Illinois               24        190230             39180
# 14               Indiana               17         76100             15470
# 15                  Iowa               27         52150             11300
# 16                Kansas               18         34380              6420
# 17              Kentucky               23         69620             15310
# 18             Louisiana               21         71050             13610
# 19                 Maine               34         25520              5610
# 20              Maryland               32         97980             18600
# 21         Massachusetts               25         90830             20020
# 22              Michigan               16        105650             23910
# 23             Minnesota               25         76550             16520
# 24           Mississippi               23         52870             13620
# 25              Missouri               21         84920             19960
# 26               Montana               36         24050              5630
# 27              Nebraska               24         29960              4830
# 28                Nevada               14         26430              4740
# 29         New Hampshire               29         18950              3600
# 30            New Jersey               27        117930             18740
# 31            New Mexico               35         52620             11350
# 32              New York               37        433960             83050
# 33        North Carolina               16        116640             19440
# 34          North Dakota               23         10790              2310
# 35                  Ohio               20        153080             34740
# 36              Oklahoma               30         84710             21200
# 37                Oregon               40        107100             19480
# 38          Pennsylvania               32        233560             50280
# 39          Rhode Island               41         27080              6350
# 40        South Carolina               26         89700             16970
# 41          South Dakota               21         11200              2560
# 42             Tennessee               22        104170             22780
# 43                 Texas               21        414860             83800
# 44                  Utah               55         38420              8730
# 45               Vermont               16         19750              3960
# 46              Virginia               31         76520             12050
# 47            Washington               66        135400             27210
# 48         West Virginia               24         77660             16770
# 49             Wisconsin               26         83110             19980
# 50               Wyoming               29          8970              2340
#
#     num_centers15  total_expend15 STATEFP20
# 0             187        69742000        01
# 1             157        10158000        02
# 2             232        57560000        04
# 3             163        11397000        05
# 4            1697       454706000        06
# 5             221        29252000        08
# 6              92        21462000        09
# 7              41         4646000        10
# 8              31         5518000        11
# 9             430        42764000        12
# 10            383        35665000        13
# 11             44         1918000        15
# 12            104        12886000        16
# 13            340        58133000        17
# 14            138        41063000        18
# 15             88        18472000        19
# 16            128        25112000        20
# 17            211        82039000        21
# 18            195        34361000        22
# 19            106         6066000        23
# 20            140        58363000        24
# 21            229        25984000        25
# 22            271        42383000        26
# 23            128        23991000        27
# 24            210        23234000        28
# 25            218        48244000        29
# 26             85         8138000        30
# 27             56         8026000        31
# 28             59        17674000        32
# 29             39         2058000        33
# 30            121        14402000        34
# 31            234         6108000        35
# 32            557       113086000        36
# 33            270        92753000        37
# 34             42         1726000        38
# 35            302        52992000        39
# 36            213        24830000        40
# 37            209        27092000        41
# 38            309        74949000        42
# 39             39          762000        44
# 40            180        11553000        45
# 41             89         2458000        46
# 42            262        57367000        47
# 43            453       157726000        48
# 44             83         6759000        49
# 45             56          896000        50
# 46            241        63923000        51
# 47            257        34585000        53
# 48            202         4026000        54
# 49            132        59224000        55
# 50             34         2196000        56

# %% [markdown]
# ## Save Cleaned Data

# %%
# planning.to_csv("../data/family_planning.csv", index=False)

# %%
test = pd.read_csv("../data/family_planning.csv", dtype={"STATEFP20": object})

# %%
test
# Out:
#                    state  perc_need_met16  num_served16  num_u20_served16  \
# 0                Alabama               28         97600             20300
# 1                 Alaska               54         21640              4750
# 2                Arizona               19         88140             16500
# 3               Arkansas               23         50960             10610
# 4             California               64       1618010            252840
# 5               Colorado               35        115490             23720
# 6            Connecticut               38         68130             14160
# 7               Delaware               30         16080              4510
# 8   District of Columbia               88         43600              7370
# 9                Florida               16        214450             40050
# 10               Georgia               26        194910             42860
# 11                Hawaii               21         13830              2560
# 12                 Idaho               18         20880              4340
# 13              Illinois               24        190230             39180
# 14               Indiana               17         76100             15470
# 15                  Iowa               27         52150             11300
# 16                Kansas               18         34380              6420
# 17              Kentucky               23         69620             15310
# 18             Louisiana               21         71050             13610
# 19                 Maine               34         25520              5610
# 20              Maryland               32         97980             18600
# 21         Massachusetts               25         90830             20020
# 22              Michigan               16        105650             23910
# 23             Minnesota               25         76550             16520
# 24           Mississippi               23         52870             13620
# 25              Missouri               21         84920             19960
# 26               Montana               36         24050              5630
# 27              Nebraska               24         29960              4830
# 28                Nevada               14         26430              4740
# 29         New Hampshire               29         18950              3600
# 30            New Jersey               27        117930             18740
# 31            New Mexico               35         52620             11350
# 32              New York               37        433960             83050
# 33        North Carolina               16        116640             19440
# 34          North Dakota               23         10790              2310
# 35                  Ohio               20        153080             34740
# 36              Oklahoma               30         84710             21200
# 37                Oregon               40        107100             19480
# 38          Pennsylvania               32        233560             50280
# 39          Rhode Island               41         27080              6350
# 40        South Carolina               26         89700             16970
# 41          South Dakota               21         11200              2560
# 42             Tennessee               22        104170             22780
# 43                 Texas               21        414860             83800
# 44                  Utah               55         38420              8730
# 45               Vermont               16         19750              3960
# 46              Virginia               31         76520             12050
# 47            Washington               66        135400             27210
# 48         West Virginia               24         77660             16770
# 49             Wisconsin               26         83110             19980
# 50               Wyoming               29          8970              2340
#
#     num_centers15  total_expend15 STATEFP20
# 0             187        69742000        01
# 1             157        10158000        02
# 2             232        57560000        04
# 3             163        11397000        05
# 4            1697       454706000        06
# 5             221        29252000        08
# 6              92        21462000        09
# 7              41         4646000        10
# 8              31         5518000        11
# 9             430        42764000        12
# 10            383        35665000        13
# 11             44         1918000        15
# 12            104        12886000        16
# 13            340        58133000        17
# 14            138        41063000        18
# 15             88        18472000        19
# 16            128        25112000        20
# 17            211        82039000        21
# 18            195        34361000        22
# 19            106         6066000        23
# 20            140        58363000        24
# 21            229        25984000        25
# 22            271        42383000        26
# 23            128        23991000        27
# 24            210        23234000        28
# 25            218        48244000        29
# 26             85         8138000        30
# 27             56         8026000        31
# 28             59        17674000        32
# 29             39         2058000        33
# 30            121        14402000        34
# 31            234         6108000        35
# 32            557       113086000        36
# 33            270        92753000        37
# 34             42         1726000        38
# 35            302        52992000        39
# 36            213        24830000        40
# 37            209        27092000        41
# 38            309        74949000        42
# 39             39          762000        44
# 40            180        11553000        45
# 41             89         2458000        46
# 42            262        57367000        47
# 43            453       157726000        48
# 44             83         6759000        49
# 45             56          896000        50
# 46            241        63923000        51
# 47            257        34585000        53
# 48            202         4026000        54
# 49            132        59224000        55
# 50             34         2196000        56
